# %%
import tensorflow as tf
import numpy as np

# %%
def house_model():
    
    #input and output tensors with the values for houses with 1 up to 6 bedrooms
    xs = np.array([0, 1, 2, 3, 4, 5, 6], dtype=float)
    ys = np.array([0.5, 1, 1.5, 2, 2.5, 3, 3.5], dtype=float)
    
    # Defining the model 
    model =  tf.keras.Sequential([tf.keras.layers.Dense(units=1, input_shape=[1])])
    
    # Compiling the model
    model.compile(optimizer='sgd', loss='mean_squared_error')
    
    # Training the model for 1000 epochs by feeding the i/o tensors
    model.fit(xs, ys, epochs=1000)
    
    return model

# %%
# Getting trained model
model = house_model()
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 397ms/step - loss: 57.3952
# Epoch 2/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 30.2381
# Epoch 3/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 15.9307
# Epoch 4/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 8.3930
# Epoch 5/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 4.4219
# Epoch 6/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.3297
# Epoch 7/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2275
# Epoch 8/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.6468
# Epoch 9/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3409
# Epoch 10/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1797
# Epoch 11/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0948
# Epoch 12/1000
# ...

# %%
#Predicting for a new value
new_x = 7.0
prediction = model.predict([new_x])[0]
print(prediction)
# Out:
# 1/1 [==============================] - 0s 56ms/step
# [4.0000563]
